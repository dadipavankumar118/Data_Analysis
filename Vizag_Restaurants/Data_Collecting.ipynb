# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://maps-data.p.rapidapi.com/searchmaps.php"

querystring = {"query":"restaurant","limit":"150","country":"us","lang":"en","lat":"17.712701","lng":"83.29022","offset":"0","zoom":"13"}

headers = {"X-RapidAPI-Key": "6ee74c43eamshfc1b45f62b8cabfp144097jsn747153f2daa5","X-RapidAPI-Host": "maps-data.p.rapidapi.com"}

response = requests.get(url, headers=headers, params=querystring)

print(response)
# Out:
# <Response [200]>

# %%
data = pd.json_normalize(response.json(),record_path=['data'])

# %%
data
# Out:
#                                business_id   phone_number  \
# 0    0x3a3942c853cfb859:0x3ff855b6be04af6d  +918912562222
# 1    0x3a39431f599b3901:0x23368c02502a97e6  +919390219693
# 2    0x3a3942e03976b615:0x9d2daa123b2ad1bc  +918912560416
# 3    0x3a39431979c7d1db:0x139a4996f502166e  +919347162019
# 4    0x3a394320a6ea13e3:0xda8aaffe779c2486  +917013015860
# ..                                     ...            ...
# 142  0x3a394368a36b0953:0xce438d7d3e54bdcb           None
# 143  0x3a3943a2cb21fadb:0xc2bc8239fb6cce7f           None
# 144  0x3a3943483030ad57:0xcad46075d7d25ed0           None
# 145  0x3a3943c826556941:0xa15a064dfa559233           None
# 146  0x3a395d3a88aff37f:0x33cb8ec720467c0c           None
#
#                                           name  \
# 0                            Bombay Restaurant
# 1            Kanhaji Restaurant, Visakhapatnam
# 2                          Kaalinga Restaurant
# 3    Ganapati Family Restaurant Vishakhapatnam
# ...

# %%
data.to_csv('vizag_restaurant.csv',index = False)
